# %%
import pandas as pd

# %%
H1 = board size – exp

H2 = action count

# %%
data = pd.read_csv('time_comparison.csv')

data
# Out:
#      num_pipes  depth   time_dfs   time_bfs time_astar time_greedy
# 0            4    NaN     0.0003     0.0003     0.0003      0.0002
# 1            4    NaN     0.0003     0.0003     0.0003      0.0003
# 2            9    NaN     0.0004     0.0004     0.0005      0.0005
# 3            9    NaN     0.0005     0.0005    0.00047      0.0006
# 4            9    NaN     0.0006     0.0006     0.0005      0.0005
# 5           16    NaN     0.0009     0.0009     0.0007      0.0008
# 6           25    NaN     0.0032    0.00154     0.0013      0.0027
# 7           25    NaN     0.0014     0.0013     0.0011      0.0018
# 8          100    NaN     0.0068     0.0072     0.3857      0.0036
# 9          225    NaN     1.3283     0.2394     0.0916      0.0709
# 10         400    NaN     0.9722     6.7018     0.0662      0.0619
# 11         625    NaN     0.7888    0.09574     0.2664      0.0242
# 12         900    NaN     0.8910     0.3977     0.0406      0.0477
# ...
